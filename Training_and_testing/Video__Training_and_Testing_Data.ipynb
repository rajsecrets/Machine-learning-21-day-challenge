# %%
import pandas as pd
df = pd.read_csv("/content/carprices.csv")
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['Mileage'], df['Sell Price($)'], marker = "*", color = 'red')

# %%
plt.scatter(df['Age(yrs)'], df['Sell Price($)'], marker = "*", color = 'red')

# %%
x = df[['Mileage', 'Age(yrs)']]
y = df['Sell Price($)']

# %%
x
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %% [markdown]
# # train test split method to make traingin and testing data

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

# %%
x_train
# Out:
#     Mileage  Age(yrs)
# 1     35000         3
# 11    79000         7
# 17    69000         5
# 15    25400         3
# 7     72000         6
# 12    59000         5
# 3     22500         2
# 14    82450         7
# 2     57000         5
# 19    52000         5
# 13    58780         4
# 0     69000         6
# 18    87600         8
# 4     46000         4
# 16    28000         2
# 9     67000         6

# %%
y_train
# Out:
# 1     34000
# 11    19500
# 17    19700
# 15    35000
# 7     19300
# 12    26000
# 3     40000
# 14    19400
# 2     26100
# 19    28200
# 13    27500
# 0     18000
# 18    12800
# 4     31500
# 16    35500
# 9     22000
# Name: Sell Price($), dtype: int64

# %% [markdown]
# random sampling

# %%
x_test
# Out:
#     Mileage  Age(yrs)
# 6     52000         5
# 5     59000         5
# 10    83000         7
# 8     91000         8

# %%
len(df)
# Out:
# 20

# %%
len(x_train)
# Out:
# 16

# %% [markdown]
# random_state = 10 then it will give the same value each time

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.predict(x_test)
# Out:
# array([27249.04328129, 25168.72036052, 16420.37704258, 13234.96133833])

# %%
reg.score(x_test,y_test)
# Out:
# 0.8635028895808303
