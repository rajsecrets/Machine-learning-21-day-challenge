# %% [markdown]
# <a href="https://colab.research.google.com/github/rajsecrets/Machine-learning-21-day-challenge/blob/main/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/content/insurance_data.csv")

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age, df.bought_insurance, color = 'red')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, test_size = 0.1)

# %%
x_train
# Out:
#     age
# 23   45
# 9    61
# 4    46
# 18   19
# 24   50
# 6    55
# 13   29
# 5    56
# 1    25
# 14   49
# 25   54
# 12   27
# 2    47
# 16   25
# 19   18
# 0    22
# 8    62
# 17   58
# 21   26
# 15   55
# 3    52
# 7    60
# 20   21
# 26   23

# %%
x_test
# Out:
#     age
# 10   18
# 11   28
# 22   40

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 0, 1])

# %%
y_test
# Out:
# 10    0
# 11    0
# 22    1
# Name: bought_insurance, dtype: int64

# %%
model.score(x_test, y_test)
# Out:
# 1.0
